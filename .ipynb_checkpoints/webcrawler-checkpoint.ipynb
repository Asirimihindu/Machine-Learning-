# %%
import requests
from bs4 import BeautifulSoup
import pprint

# %%
res= requests.get('https://news.ycombinator.com/news')
soup= BeautifulSoup(res.text,'html.parser')
print(soup.find_all('a'))
# Out:
# [<a href="https://news.ycombinator.com"><img height="18" src="y18.gif" style="border:1px white solid;" width="18"/></a>, <a href="news">Hacker News</a>, <a href="newest">new</a>, <a href="front">past</a>, <a href="newcomments">comments</a>, <a href="ask">ask</a>, <a href="show">show</a>, <a href="jobs">jobs</a>, <a href="submit">submit</a>, <a href="login?goto=news">login</a>, <a href="vote?id=22839943&amp;how=up&amp;goto=news" id="up_22839943"><div class="votearrow" title="upvote"></div></a>, <a class="storylink" href="https://www.inputmag.com/tech/ibm-will-offer-free-cobol-training-to-address-overloaded-unemployment-systems">IBM will offer free COBOL training</a>, <a href="from?site=inputmag.com"><span class="sitestr">inputmag.com</span></a>, <a class="hnuser" href="user?id=jacobedawson">jacobedawson</a>, <a href="item?id=22839943">1 hour ago</a>, <a href="hide?id=22839943&amp;goto=news">hide</a>, <a href="item?id=22839943">9 comments</a>, <a href="vote?id=22834524&amp;how=up&amp;g
# ...

# %%
print(soup.title)
# Out:
# <title>Hacker News</title>

# %%
links=soup.select('.storylink') 
subtext=soup.select('.subtext')

# %%
def create_custom_hn(links, subtext):
    hn=[]
    for idx, item in enumerate(links):
        title=links[idx].getText()
        href=links[idx].get('href',None)
        vote=subtext[idx].select('.score')
        if len(vote):
            points=int(vote[0].getText().replace(' points',''))
            if points>50:
                hn.append({'title':title,'link':href ,'votes':points})
    return hn

# %%
def sort_stories_by_votes(hnlist):
    return sorted(hnlist, key= lambda k:k['votes'] ,reverse= True)

# %%
sort_stories_by_votes(create_custom_hn(links, subtext))
# Out:
# [{'title': 'Apple and Google partner on Covid-19 contact tracing technology',
#   'link': 'https://www.apple.com/newsroom/2020/04/apple-and-google-partner-on-covid-19-contact-tracing-technology/',
#   'votes': 750},
#  {'title': 'A man owns the most advanced private air force after buying 46 F/A-18s',
#   'link': 'https://www.thedrive.com/the-war-zone/32869/this-man-owns-the-worlds-most-advanced-private-air-force-after-buying-46-f-a-18-hornets',
#   'votes': 575},
#  {'title': 'Senate Stock Watcher',
#   'link': 'https://senatestockwatcher.com',
#   'votes': 504},
#  {'title': 'COBOL programmers answer call',
#   'link': 'https://spectrum.ieee.org/tech-talk/computing/software/cobol-programmers-answer-call-unemployment-benefits-systems',
#   'votes': 274},
#  {'title': 'First look at Apple/Google contact tracing framework',
#   'link': 'https://twitter.com/moxie/status/1248707315626201088',
#   'votes': 143},
# ...

# %%
links[0]
# Out:
# <a class="storylink" href="https://www.inputmag.com/tech/ibm-will-offer-free-cobol-training-to-address-overloaded-unemployment-systems">IBM will offer free COBOL training</a>

# %%
q=subtext[0].select('.score')
q
# Out:
# [<span class="score" id="score_22839943">42 points</span>]

# %%
q[0]
# Out:
# <span class="score" id="score_22839943">42 points</span>

# %%
from bs4 import BeautifulSoup
import requests

# Start the session
session = requests.Session()

# Create the payload
payload = {'USER_ID':'ceb','USER_PWNO':'MdM@CeB21@'}

# Post the payload to the site to log in
s = session.post("http://10.160.1.35:8080/mdms/login", data=payload , 
	headers = dict(referer="http://10.160.1.35:8080/mdms/login"))

# Navigate to the next page and scrape the data
s = session.get('http://10.160.1.35:8080/mdms/main.do', headers = dict(referer = 'http://10.160.1.35:8080/mdms/main.do'))

soup1 = BeautifulSoup(s.text,'lxml')
inputs= soup1.select('span')
inputs
# Out:
# [<span>Meter Data Management System</span>,
#  <span>Meter Data Management System</span>,
#  <span>Meter Data Management System</span>,
#  <span>Meter Data Management System</span>,
#  <span>Meter Data Management System</span>,
#  <span>Meter Data Management System</span>,
#  <span class="ns_user">
#  <em>CEBUSer</em><a class="ns_logout" href="/mdms/logout">Logout</a>
#  </span>,
#  <span class="navi_home">홈</span>,
#  <span>10</span>,
#  <span>Main</span>,
#  <span id="pCnt">0</span>,
#  <span id="mrRate">0</span>,
#  <span><em id="mrSCnt1"></em><span id="em_cntRate1"></span></span>,
#  <span id="em_cntRate1"></span>,
#  <span><em id="mrSCnt2"></em><span id="em_cntRate2"></span></span>,
#  <span id="em_cntRate2"></span>,
#  <span><em id="mrSCnt3"></em><span id="em_cntRate3"></span></span>,
#  <span id="em_cntRate3"></span>,
#  <span class="mc_location">
#  <a class="current" id="map_main" onclick="fn_map_main()">All Areas</a>
#  <a id="map_detail" style="display: none;"></a>
# ...

# %%
from bs4 import BeautifulSoup
import requests

# Start the session
session = requests.Session()

# Create the payload
payload = {'accountid':'admin','password':'1234'}

# Post the payload to the site to log in
s = session.post('http://10.160.0.44:8085/aimir-web/admin/login.do', data=payload , 
	headers = dict(referer="http://10.160.0.44:8085/aimir-web/admin/login.do"))

# Navigate to the next page and scrape the data
s = session.get('http://10.160.0.44:8085/aimir-web/gadget/index.jsp', headers = dict(referer = 'http://10.160.0.44:8085/aimir-web/gadget/index.jsp'))

soup1 = BeautifulSoup(s.text, 'html.parser')
soup1.title
# Out:
# <title>AiMiR 3.0 - Portal</title>

# %%
session.delete('http://10.160.0.44:8085/aimir-web/gadget/index.jsp')
# Out:
# <Response [405]>

# %%
res= requests.get('https://en.wikipedia.org/wiki/COBOL')
soup= BeautifulSoup(res.text,'html.parser')
soup.title
# Out:
# <title>COBOL - Wikipedia</title>

# %%
#selectiing tags by class name 
soup.select('.mw-redirect')
# Out:
# [<a class="mw-redirect" href="/wiki/Kobol" title="Kobol">Kobol</a>,
#  <a class="mw-redirect" href="/wiki/Software_developer" title="Software developer">Developers</a>,
#  <a class="mw-redirect" href="/wiki/ANSI" title="ANSI">ANSI</a>,
#  <a class="mw-redirect" href="/wiki/ISO" title="ISO">ISO</a>,
#  <a class="mw-redirect" href="/wiki/Weak_typing" title="Weak typing">Weak</a>,
#  <a class="mw-redirect" href="/wiki/Static_typing" title="Static typing">static</a>,
#  <a class="mw-redirect" href="/wiki/FACT_computer_language" title="FACT computer language">FACT</a>,
#  <a class="mw-redirect" href="/wiki/Compiled" title="Compiled">compiled</a>,
#  <a class="mw-redirect" href="/wiki/Computer_programming_language" title="Computer programming language">computer programming language</a>,
#  <a class="mw-redirect" href="/wiki/US_Department_of_Defense" title="US Department of Defense">US Department of Defense</a>,
# ...

# %%
#selectiing by tag name 
soup.find_all('a')
# Out:
# [<a id="top"></a>,
#  <a href="/wiki/Wikipedia:Good_articles" title="This is a good article. Click here for more information."><img alt="This is a good article. Click here for more information." data-file-height="185" data-file-width="180" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/19px-Symbol_support_vote.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/29px-Symbol_support_vote.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/39px-Symbol_support_vote.svg.png 2x" width="19"/></a>,
#  <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>,
#  <a class="mw-jump-link" href="#p-search">Jump to search</a>,
#  <a class="mw-redirect" href="/wiki/Kobol" title="Kobol">Kobol</a>,
# ...

# %%
soup1.title
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e2ee63742338> in <module>
# ----> 1 soup1.title
#
# NameError: name 'soup1' is not defined

# %%
from bs4 import BeautifulSoup
import requests

# Start the session
session = requests.Session()

# Create the payload
payload = {'USER_ID':'ceb','USER_PWNO':'MdM@CeB21@'}

# Post the payload to the site to log in
s = session.post("http://10.160.1.35:8080/mdms/login", data=payload , 
	headers = dict(referer="http://10.160.1.35:8080/mdms/login"))

# Navigate to the next page and scrape the data
s = session.get('http://10.160.1.35:8080/mdms/main.do', headers = dict(referer = 'http://10.160.1.35:8080/mdms/main.do'))

soup1 = BeautifulSoup(s.text, 'html.parser')
inputs= soup1.select('span')
inputs
# Out:
# [<span>Meter Data Management System</span>,
#  <span>Meter Data Management System</span>,
#  <span>Meter Data Management System</span>,
#  <span>Meter Data Management System</span>,
#  <span>Meter Data Management System</span>,
#  <span>Meter Data Management System</span>,
#  <span class="ns_user">
#  <em>CEBUSer</em><a class="ns_logout" href="/mdms/logout">Logout</a>
#  </span>,
#  <span class="navi_home">홈</span>,
#  <span>10</span>,
#  <span>Main</span>,
#  <span id="pCnt">0</span>,
#  <span id="mrRate">0</span>,
#  <span><em id="mrSCnt1"></em><span id="em_cntRate1"></span></span>,
#  <span id="em_cntRate1"></span>,
#  <span><em id="mrSCnt2"></em><span id="em_cntRate2"></span></span>,
#  <span id="em_cntRate2"></span>,
#  <span><em id="mrSCnt3"></em><span id="em_cntRate3"></span></span>,
#  <span id="em_cntRate3"></span>,
#  <span class="mc_location">
#  <a class="current" id="map_main" onclick="fn_map_main()">All Areas</a>
#  <a id="map_detail" style="display: none;"></a>
# ...

# %%
# Out:
# 'Apache Tomcat/8.0.48 - Error reportH1 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:22px;} H2 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:16px;} H3 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:14px;} BODY {font-family:Tahoma,Arial,sans-serif;color:black;background-color:white;} B {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;} P {font-family:Tahoma,Arial,sans-serif;background:white;color:black;font-size:12px;}A {color : black;}A.name {color : black;}.line {height: 1px; background-color: #525D76; border: none;} HTTP Status 404 - /mdms/pdo100.dotype Status reportmessage /mdms/pdo100.dodescription The requested resource is not available.Apache Tomcat/8.0.48'
